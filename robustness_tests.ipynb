# %%
# !python test_widerface.py --trained_model weights/Resnet50_Final.pth --network resnet50
# !python test_widerface.py --trained_model weights/mobilenet0.25_Final.pth --network mobile0.25
# Out:
# Loading pretrained model from weights/mobilenet0.25_Final.pth
# remove prefix 'module.'
# Missing keys:0
# Unused checkpoint keys:0
# Used keys:300
# Finished loading model!
# RetinaFace(
#   (body): IntermediateLayerGetter(
#     (stage1): Sequential(
#       (0): Sequential(
#         (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#         (3): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# %cd widerface_evaluate
# !python setup.py build_ext --inplace
# !python evaluation.py
# Out:
# /common/home/users/n/nicoleoo.2021/Pytorch_Retinaface/widerface_evaluate
# /common/home/users/n/nicoleoo.2021/jupyterlab-venv-pytorch-240/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# ...
# Processing hard: 100%|██████████████████████████| 61/61 [00:26<00:00,  2.29it/s]
# ==================== Results ====================
# Easy   Val AP: 0.2638074350042493
# Medium Val AP: 0.19603723605134335
# Hard   Val AP: 0.09948036545651089
# ...

# %%
# !python test_fddb.py --trained_model weights/Resnet50_Final.pth --network resnet50

# %%
import os
for root, dirs, files in os.walk('widerface_txt'):
    for f in files:
        if not f.endswith('.txt'):
            print(f"[WARNING] Non-txt file: {f}")

# %%
with open('widerface_txt/0--Parade/0_Parade_marchingband_1_465.txt', 'r') as f:
    lines = f.readlines()
    print("First line:", lines[0].strip())
